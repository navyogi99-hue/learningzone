# %%
import sqlalchemy

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///studentsv2.db', echo=True)

# %%
# create Models
from sqlalchemy import Column, Integer, String
from sqlalchemy.orm import DeclarativeBase

class Base(DeclarativeBase):
    pass
class Student(Base):
    __tablename__ = 'student'
    id = Column(Integer, primary_key=True)
    name = Column(String(100))
    email = Column(String(100))
    def __repr__(self):
        return f"Student(id={self.id}, name='{self.name}', age={self.age}, email='{self.email}')"

# to create all tables
Base.metadata.create_all(engine)
# Out:
# 2026-05-26 15:16:29,617 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-05-26 15:16:29,627 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("student")
# 2026-05-26 15:16:29,632 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-05-26 15:16:29,641 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("student")
# 2026-05-26 15:16:29,648 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-05-26 15:16:29,654 INFO sqlalchemy.engine.Engine
# CREATE TABLE student (
# 	id INTEGER NOT NULL,
# 	name VARCHAR(100),
# 	email VARCHAR(100),
# 	PRIMARY KEY (id)
# )
#
#
# 2026-05-26 15:16:29,656 INFO sqlalchemy.engine.Engine [no key 0.00230s] ()
# 2026-05-26 15:16:29,669 INFO sqlalchemy.engine.Engine COMMIT

# %%
#sessions manages DB operations
from sqlalchemy.orm import sessionmaker
Session = sessionmaker(bind=engine)
session = Session()

# %%
students = Student(name="Ajay", email="ajay@example.com")
session.add(students)
session.commit()
# Out:
# 2026-05-26 15:21:35,150 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-05-26 15:21:35,174 INFO sqlalchemy.engine.Engine INSERT INTO student (name, email) VALUES (?, ?)
# 2026-05-26 15:21:35,177 INFO sqlalchemy.engine.Engine [generated in 0.00375s] ('Ajay', 'ajay@example.com')
# 2026-05-26 15:21:35,189 INFO sqlalchemy.engine.Engine COMMIT

# %%
student = Student(name='Alice', email='alice@example.com')
session.add(student)
session.commit()
# Out:
# 2026-05-26 15:22:32,661 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-05-26 15:22:32,665 INFO sqlalchemy.engine.Engine INSERT INTO student (name, email) VALUES (?, ?)
# 2026-05-26 15:22:32,668 INFO sqlalchemy.engine.Engine [cached since 57.5s ago] ('Alice', 'alice@example.com')
# 2026-05-26 15:22:32,705 INFO sqlalchemy.engine.Engine COMMIT

# %%
# Querry
students = session.query(Student).all()

for student in students:
    print(student)
# Out:
# 2026-05-26 15:31:47,269 INFO sqlalchemy.engine.Engine SELECT student.id AS student_id, student.name AS student_name, student.email AS student_email
# FROM student
# 2026-05-26 15:31:47,451 INFO sqlalchemy.engine.Engine [cached since 498.1s ago] ()
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 5
#       1 # Querry
#       2 students = session.query(Student).all()
#       3
#       4 for student in students:
# ----> 5     print(student)
#
# Cell In[7], line 13, in Student.__repr__(self)
#      12 def __repr__(self):
# ---> 13     return f"Student(id={self.id}, name='{self.name}', age={self.age}, email='{self.email}')"
#
# AttributeError: 'Student' object has no attribute 'age'
