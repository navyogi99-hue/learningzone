# %%
from langchain_core.messages import SystemMessage, HumanMessage
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
import os

# %%
load_dotenv()
project = os.getenv('GOOGLE_CLOUD_PROJECT')
llm = ChatGoogleGenerativeAI(
    model = "gemini-2.5-flash-lite",
    vertexai = True,
    project = project
)

# %%
from langchain_core.prompts import PromptTemplate

template = PromptTemplate(
    input_variable=["country"],
    template="What is capital of the {country}"
)

# %%
template.format(country = "India")
# Out:
# 'What is capital of the India'

# %%
chain = template | llm 
response = chain.invoke({"country": "India"})
response.content
# Out:
# 'The capital of India is **New Delhi**.'

# %%
template = PromptTemplate(
    input_variables=["country", "topic"],
    template="Explain about {topic} with respect to {country}"
)
chain = template | llm
response = chain.invoke({"country": "India", "topic": "Independence"})
response.content
# Out:
# '## India\'s Independence: A Journey Towards Self-Rule\n\nIndia\'s independence, celebrated on **August 15, 1947**, marks the culmination of a long and arduous struggle against British colonial rule. It was a moment of profound significance, not just for India but for the global decolonization movement, ushering in a new era of self-determination for millions.\n\n**The Seeds of Independence: A Long and Complex Struggle**\n\nThe desire for self-rule in India wasn\'t a sudden outburst but a gradual evolution fueled by a multitude of factors:\n\n* **Early Resistance:** While often overlooked, there were early instances of resistance against British dominance, such as the **Sepoy Mutiny of 1857 (First War of Indian Independence)**. Though brutally suppressed, it ignited a sense of national consciousness and a desire to reclaim sovereignty.\n* **Rise of Nationalism:** The late 19th and early 20th centuries witnessed the emergence of organized nationalist movements. Key organizations like the **Indian National Congress (INC)**, founded in 1885, initially aimed for greater Indian representation within the British system but gradually transformed into a powerful force demanding full independence.\n* **Ideological Influences:** Ideas of liberty, equality, and self-determination, propagated by thinkers like Mazzini and Garibaldi, resonated with Indian intellectuals. The success of other independence movements also served as inspiration.\n* **Economic Exploitation:** British policies, focused on extracting resources and promoting their own industries, led to widespread poverty and economic hardship in India. This fueled resentment and a desire to control their own economic destiny.\n* **Social and Cultural Awakening:** The 19th century saw a "Bengal Renaissance" and similar movements across India, leading to a revival of Indian culture, a questioning of social injustices, and a reassertion of Indian identity, which indirectly contributed to the demand for political independence.\n* **Key Leaders and Movements:** The struggle for independence was shaped by the ideologies and actions of numerous leaders and movements:\n    * **Mahatma Gandhi:** The "Father of the Nation," Gandhi\'s philosophy of **Satyagraha (non-violent civil disobedience)** and **Ahimsa (non-violence)** galvanized millions. His campaigns like the Non-Cooperation Movement, the Salt March, and the Quit India Movement were pivotal in pressuring the British.\n    * **Jawaharlal Nehru:** The first Prime Minister of India, Nehru was a key architect of modern India, advocating for secularism, democracy, and a planned economy.\n    * **Sardar Vallabhbhai Patel:** Known as the "Iron Man of India," Patel played a crucial role in integrating the princely states into the Indian Union.\n    * **Subhas Chandra Bose:** A charismatic leader who believed in more assertive methods, Bose formed the Indian National Army (INA) to fight the British during World War II.\n    * **Bhagat Singh, Chandrashekhar Azad, and others:** Revolutionary leaders who believed in armed struggle and made immense sacrifices.\n    * **Women\'s Participation:** Women played a significant role in the freedom struggle, actively participating in protests, boycotts, and organizing.\n\n**The Final Push and Partition**\n\nWorld War II significantly weakened the British Empire. The war effort had drained their resources, and the global political landscape was shifting. The Quit India Movement during the war intensified the pressure.\n\nHowever, the road to independence was tragically marred by the **Partition of India**. Driven by religious and political tensions, the British government decided to divide the subcontinent into two independent nations: India and Pakistan. This decision, implemented hastily and without adequate planning, led to:\n\n* **Massive Violence and Displacement:** The Partition resulted in one of the largest and most brutal migrations in human history, with millions of people displaced and hundreds ...
